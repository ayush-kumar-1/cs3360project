# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import sklearn 

# %matplotlib inline

# %%
chess = pd.read_csv("games.csv")
chess.head()
# Out:
#          id  rated    created_at  last_move_at  turns victory_status winner  \
# 0  TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime  white
# 1  l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign  black
# 2  mIICvQHh   True  1.504130e+12  1.504130e+12     61           mate  white
# 3  kWKvrqYL   True  1.504110e+12  1.504110e+12     61           mate  white
# 4  9tXo1AUZ   True  1.504030e+12  1.504030e+12     95           mate  white
#
#   increment_code       white_id  white_rating      black_id  black_rating  \
# 0           15+2       bourgris          1500          a-00          1191
# 1           5+10           a-00          1322     skinnerua          1261
# 2           5+10         ischia          1496          a-00          1500
# 3           20+0  daniamurashov          1439  adivanov2009          1454
# 4           30+3      nik221107          1523  adivanov2009          1469
#
# ...

# %%
openings = set(list(chess.opening_name))
print(len(openings))
# Out:
# 1477

# %%
opening_generalizer = lambda o: o[:o.find(":")]
generalized_openings = set(list(map(opening_generalizer, openings)))

# %%
generalized_openings
# Out:
# {'Alekhine Defens',
#  'Alekhine Defense',
#  'Alekhine Defense #',
#  'Amar Openin',
#  'Amazon Attac',
#  'Amazon Attack',
#  'Anderssen Openin',
#  'Australian Defens',
#  'Barnes Defens',
#  'Barnes Opening',
#  'Benko Gambi',
#  'Benko Gambit',
#  'Benko Gambit Accepted |  Fianchetto Variatio',
#  'Benko Gambit Accepted |  Fully Accepted Variatio',
#  'Benko Gambit Accepted |  Modern Variatio',
#  'Benko Gambit Accepted |  Pawn Return Variatio',
#  'Benko Gambit Accepted |  Yugoslav |  without 7...Bxf',
#  'Benko Gambit Declined |  Hjoerring Countergambi',
#  'Benko Gambit Declined |  Main Lin',
#  'Benko Gambit Declined |  Quiet Lin',
#  'Benoni Defens',
#  'Benoni Defense',
#  'Bird Openin',
#  'Bird Opening',
#  "Bishop's Openin",
#  "Bishop's Opening",
#  'Blackmar-Diemer Gambi',
#  'Blackmar-Diemer Gambit',
#  'Blackmar-Diemer Gambit #',
#  'Blackmar-Diemer Gambit Declined |  Brombacher Countergambi',
#  'Blackmar-Diemer Gambit Declined |  Lamb Defens',
# ...

# %% [raw]
# # Feature Selection and Extraction
#
#
# Response Variable: White Wins (True or False)
#
# 1. Rating Difference (White - Black)
# 2. Generalized Opening Code
# 3. Time Control
# 4. Rated (True or False)
# 5. Number of Moves?
# 6. Victory Status?
